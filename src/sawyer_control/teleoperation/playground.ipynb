# %%
import pickle

file_path = '/home/tung/workspace/rlhf_bench/iql-pytorch-sawyer/datasets/sawyer-pick-lift-banana-v0/failed_trajectories/sawyer-pick-lift-banana-v0_episode_1.pkl'

# Open the file in 'rb' (read-binary) mode
with open(file_path, 'rb') as file:
    # Load the data from the file
    data = pickle.load(file)

print(data)
# Out:
# [{'observation': array([ 0.1775989 ,  0.12168404, -0.26344293,  0.07360797,  0.09504851,
#        -0.02037844, -0.10399092, -0.02663553,  0.24306448,  1.        ],
#       dtype=float32), 'action': array([ 0.01140753, -0.31879058, -0.13512039,  0.        ,  1.        ]), 'reward': 0.13110068718984969, 'done': False, 'metadata': None}, {'observation': array([ 0.17667016,  0.11376268, -0.26039785,  0.07351967,  0.09508716,
#        -0.02043096, -0.10315049, -0.01867552,  0.2399669 ,  1.        ],
#       dtype=float32), 'action': array([-0.05743738, -0.38501471, -0.19626799,  0.        ,  1.        ]), 'reward': 0.13589636161301144, 'done': False, 'metadata': None}, {'observation': array([ 0.17970072,  0.10403725, -0.2547991 ,  0.07462255,  0.0946649 ,
#        -0.01961949, -0.10507817, -0.00937235,  0.2351796 ,  1.        ],
# ...

# %%
import os 

file_path_arr = []
for filename in os.listdir("/home/tung/workspace/rlhf_bench/iql-pytorch-sawyer/datasets/sawyer-drawer-open-v0/successful_trajectories"):
    file_path = os.path.join("/home/tung/workspace/rlhf_bench/iql-pytorch-sawyer/datasets/sawyer-drawer-open-v0/successful_trajectories", filename)
    file_path_arr.append(file_path)
    # if os.path.isfile(file_path):
    #     os.remove(file_path)
# file_path = 
# os.remove(file_path)

# %%
file_path_arr
# Out:
# ['/home/tung/workspace/rlhf_bench/iql-pytorch-sawyer/datasets/sawyer-drawer-open-v0/successful_trajectories/sawyer-drawer-open-v0_episode_3.pkl',
#  '/home/tung/workspace/rlhf_bench/iql-pytorch-sawyer/datasets/sawyer-drawer-open-v0/successful_trajectories/sawyer-drawer-open-v0_episode_4.pkl',
#  '/home/tung/workspace/rlhf_bench/iql-pytorch-sawyer/datasets/sawyer-drawer-open-v0/successful_trajectories/sawyer-drawer-open-v0_episode_1.pkl',
#  '/home/tung/workspace/rlhf_bench/iql-pytorch-sawyer/datasets/sawyer-drawer-open-v0/successful_trajectories/sawyer-drawer-open-v0_episode_5.pkl',
#  '/home/tung/workspace/rlhf_bench/iql-pytorch-sawyer/datasets/sawyer-drawer-open-v0/successful_trajectories/sawyer-drawer-open-v0_episode_25.pkl',
#  '/home/tung/workspace/rlhf_bench/iql-pytorch-sawyer/datasets/sawyer-drawer-open-v0/successful_trajectories/sawyer-drawer-open-v0_episode_2.pkl']

# %%
for i in range(6,len(file_path_arr)):
    filename = f"/home/tung/workspace/rlhf_bench/iql-pytorch-sawyer/datasets/sawyer-drawer-open-v0/successful_trajectories/sawyer-drawer-open-v0_episode_{i}.pkl"
    os.remove(filename)
